# %%
load_attach_path("/mnt/c/users/phili/SAGEMATH/SPAM_Applications")
load("startup.sage")

# %%
portfolio2_data = ((1,1003/1000,1005/1000,1007/1000,1002/1000,1001/1000,1005/1000,1004/1000,1004/1000,1008/1000,1007/1000,1002/1000,1002/1000,1002/1000,1002/1000,1,1002/1000,1004/1000,1004/1000,999/1000,997/1000,1007/1000,996/1000,1002/1000),(1044/1000,1015/1000,1024/1000,1027/1000,1040/1000,995/1000,1044/1000,1060/1000,1,1030/1000,963/1000,1005/1000,960/1000,1035/1000,1047/1000,978/1000,1048/1000,1029/1000,1076/1000,1002/1000,1008/1000,958/1000,1056/1000,980/1000),(1068/1000,1051/1000,1062/1000,980/1000,991/1000,969/1000,1086/1000,1043/1000,963/1000,949/1000,1034/1000,1022/1000,972/1000,1050/1000,1042/1000,908/1000,1146/1000,1018/1000,1015/1000,909/1000,1063/1000,1064/1000,1071/1000,1070/1000),(1016/1000,1039/1000,994/1000,971/1000,1009/1000,1030/1000,1007/1000,1023/1000,1040/1000,1012/1000,1023/1000,995/1000,962/1000,1043/1000,1003/1000,1021/1000,1009/1000,1,1048/1000,1030/1000,1009/1000,983/1000,1016/1000,1012/1000),(1035/1000,1046/1000,1008/1000,989/1000,1021/1000,997/1000,1024/1000,1028/1000,1038/1000,1011/1000,943/1000,999/1000,983/1000,1021/1000,1044/1000,1031/1000,1003/1000,1005/1000,1058/1000,986/1000,1017/1000,976/1000,1038/1000,974/1000),(1032/1000,1047/1000,1010/1000,973/1000,1020/1000,989/1000,1028/1000,1040/1000,1040/1000,1070/1000,974/1000,995/1000,935/1000,987/1000,1023/1000,1002/1000,1034/1000,969/1000,1063/1000,977/1000,1002/1000,991/1000,1057/1000,987/1000),(1004/1000,1028/1000,1021/1000,985/1000,1020/1000,1020/1000,991/1000,1018/1000,999/1000,1039/1000,1016/1000,1018/1000,1002/1000,1010/1000,1008/1000,1008/1000,1002/1000,1001/1000,1009/1000,996/1000,1014/1000,983/1000,1032/1000,981/1000),(987/1000,1049/1000,1036/1000,1053/1000,996/1000,999/1000,1026/1000,1053/1000,985/1000,1028/1000,1048/1000,1023/1000,1016/1000,1016/1000,954/1000,1013/1000,1024/1000,1009/1000,999/1000,936/1000,1042/1000,1006/1000,1023/1000,1059/1000),(1014/1000,1073/1000,1002/1000,977/1000,1030/1000,1007/1000,999/1000,1003/1000,1015/1000,1029/1000,1055/1000,1,979/1000,969/1000,987/1000,1012/1000,1013/1000,1035/1000,1012/1000,969/1000,995/1000,996/1000,1023/1000,994/1000))
bddbsa = BasicSemialgebraicSet_veronese(poly_ring=PolynomialRing(QQ, ['mu']))
bddbsa.add_linear_constraint((-1,), 0, operator.lt)
complex = SemialgebraicComplex(setup_portfolio_lp, ['mu'], find_region_type=solve_for_optimal_portfolio, bddbsa=bddbsa, hist_data=portfolio2_data)
complex.bfs_completion(var_value=[10])
# Out:
# INFO: 2021-03-25 17:04:49,719 Initialized ParametricRealField(names = ['mu'], values = [10])
# INFO: 2021-03-25 17:04:49,722 New constraint: -mu < 0
# --Return--
# > /home/philipblaine/.sage/temp/DESKTOP-27I4PM7/489/parametric.sageld7ifo68.py(1109)record_factor()->None
# -> pdb.set_trace()
# (Pdb) continue
# INFO: 2021-03-25 17:05:12,357 New constraint: -mu + 6000/6047 < 0
# --Return--
# > /home/philipblaine/.sage/temp/DESKTOP-27I4PM7/489/parametric.sageld7ifo68.py(1109)record_factor()->None
# -> pdb.set_trace()
# (Pdb) up
# > /home/philipblaine/.sage/temp/DESKTOP-27I4PM7/489/parametric.sageld7ifo68.py(964)assume_comparison()
# -> self.record_factor(new_fac, op)
# (Pdb) up
# > /mnt/c/users/phili/SAGEMATH/cutgeneratingfunctionology/cutgeneratingfunctionology/spam/parametric_real_field_element.py(153)_richcmp_()
# -> left.parent().assume_comparison(right, operator.lt, left)
# (Pdb) up
# > /mnt/c/users/phili/SAGEMATH/cutgeneratingfunctionology/cutgeneratingfunctionology/spam/parametric_real_field_element.py(61)__init__()
# -> RR(value)
# (Pdb) list
#  56  	            ## Test coercing the value to RR, so that we do not try to build a ParametricRealFieldElement
#  57  	            ## from something like a tuple or vector or list or variable of a polynomial ring
#  58  	            ## or something else that does not make any sense.
#  59  	            from sage.interfaces.mathematica import MathematicaElement
#  60  	            if not isinstance(value, MathematicaElement):
#  61  ->	                RR(value)
#  62  	            self._val = value
#  63  	        if symbolic is None:
#  64  	            self._sym = value # changed to not coerce into SR. -mkoeppe
#  65  	        else:
#  66  	            self._sym = symbolic
# (Pdb) where
#   /usr/lib/python3.8/runpy.py(194)_run_module_as_main()
# -> return _run_code(code, main_globals, None,
#   /usr/lib/python3.8/runpy.py(87)_run_code()
# -> exec(code, run_globals)
#   /mnt/c/users/phili/SAGEMATH/sage-9.3.beta7/local/lib/python3.8/site-packages/sage/repl/ipython_kernel/__main__.py(3)<module>()
# -> IPKernelApp.launch_instance(kernel_class=SageKernel)
#   /mnt/c/users/phili/SAGEMATH/sage-9.3.beta7/local/lib/python3.8/site-packages/traitlets/config/application.py(664)launch_instance()
# -> app.start()
#   /mnt/c/users/phili/SAGEMATH/sage-9.3.beta7/local/lib/python3.8/site-packages/ipykernel/kernelapp.py(583)start()
# -> self.io_loop.start()
#   /mnt/c/users/phili/SAGEMATH/sage-9.3.beta7/local/lib/python3.8/site-packages/tornado/platform/asyncio.py(149)start()
# -> self.asyncio_loop.run_forever()
#   /usr/lib/python3.8/asyncio/base_events.py(570)run_forever()
# -> self._run_once()
#   /usr/lib/python3.8/asyncio/base_events.py(1859)_run_once()
# -> handle._run()
#   /usr/lib/python3.8/asyncio/events.py(81)_run()
# -> self._context.run(self._callback, *self._args)
#   /mnt/c/users/phili/SAGEMATH/sage-9.3.beta7/local/lib/python3.8/site-packages/tornado/ioloop.py(690)<lambda>()
# -> lambda f: self._run_callback(functools.partial(callback, future))
#   /mnt/c/users/phili/SAGEMATH/sage-9.3.beta7/local/lib/python3.8/site-packages/tornado/ioloop.py(743)_run_callback()
# -> ret = callback()
#   /mnt/c/users/phili/SAGEMATH/sage-9.3.beta7/local/lib/python3.8/site-packages/tornado/gen.py(787)inner()
# -> self.run()
#   /mnt/c/users/phili/SAGEMATH/sage-9.3.beta7/local/lib/python3.8/site-packages/tornado/gen.py(748)run()
# -> yielded = self.gen.send(value)
#   /mnt/c/users/phili/SAGEMATH/sage-9.3.beta7/local/lib/python3.8/site-packages/ipykernel/kernelbase.py(365)process_one()
# -> yield gen.maybe_future(dispatch(*args))
#   /mnt/c/users/phili/SAGEMATH/sage-9.3.beta7/local/lib/python3.8/site-packages/tornado/gen.py(209)wrapper()
# -> yielded = next(result)
#   /mnt/c/users/phili/SAGEMATH/sage-9.3.beta7/local/lib/python3.8/site-packages/ipykernel/kernelbase.py(268)dispatch_shell()
# -> yield gen.maybe_future(handler(stream, idents, msg))
#   /mnt/c/users/phili/SAGEMATH/sage-9.3.beta7/local/lib/python3.8/site-packages/tornado/gen.py(209)wrapper()
# -> yielded = next(result)
#   /mnt/c/users/phili/SAGEMATH/sage-9.3.beta7/local/lib/python3.8/site-packages/ipykernel/kernelbase.py(543)execute_request()
# -> self.do_execute(
#   /mnt/c/users/phili/SAGEMATH/sage-9.3.beta7/local/lib/python3.8/site-packages/tornado/gen.py(209)wrapper()
# -> yielded = next(result)
#   /mnt/c/users/phili/SAGEMATH/sage-9.3.beta7/local/lib/python3.8/site-packages/ipykernel/ipkernel.py(300)do_execute()
# -> res = shell.run_cell(code, store_history=store_history, silent=silent)
#   /mnt/c/users/phili/SAGEMATH/sage-9.3.beta7/local/lib/python3.8/site-packages/ipykernel/zmqshell.py(536)run_cell()
# -> return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   /mnt/c/users/phili/SAGEMATH/sage-9.3.beta7/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py(2857)run_cell()
# -> result = self._run_cell(
#   /mnt/c/users/phili/SAGEMATH/sage-9.3.beta7/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py(2886)_run_cell()
# -> return runner(coro)
#   /mnt/c/users/phili/SAGEMATH/sage-9.3.beta7/local/lib/python3.8/site-packages/IPython/core/async_helpers.py(68)_pseudo_sync_runner()
# -> coro.send(None)
#   /mnt/c/users/phili/SAGEMATH/sage-9.3.beta7/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py(3062)run_cell_async()
# -> has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   /mnt/c/users/phili/SAGEMATH/sage-9.3.beta7/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py(3254)run_ast_nodes()
# -> if (await self.run_code(code, result,  async_=asy)):
#   /mnt/c/users/phili/SAGEMATH/sage-9.3.beta7/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py(3331)run_code()
# -> exec(code_obj, self.user_global_ns, self.user_ns)
#   <ipython-input-2-de435918363f>(5)<module>()
# -> complex.bfs_completion(var_value=[Integer(10)])
#   /home/philipblaine/.sage/temp/DESKTOP-27I4PM7/489/parametric.sageld7ifo68.py(2406)bfs_completion()
# -> self.add_new_component(var_value, bddbsa=bddbsa, polynomial_map=polynomial_map, pos_poly=no_crossing, flip_ineq_step=flip_ineq_step, wall_crossing_method=wall_crossing_method, goto_lower_dim=goto_lower_dim, num_eq=num_eq)
#   /home/philipblaine/.sage/temp/DESKTOP-27I4PM7/489/parametric.sageld7ifo68.py(2160)add_new_component()
# -> new_component = self._cell_class(self.family, var_value,
#   /home/philipblaine/.sage/temp/DESKTOP-27I4PM7/489/parametric.sageld7ifo68.py(1673)__classcall__()
# -> return super(ProofCell, cls).__classcall__(cls, family, var_value, find_region_type, bddbsa, polynomial_map)
#   /mnt/c/users/phili/SAGEMATH/cutgeneratingfunctionology/cutgeneratingfunctionology/igp/class_call.py(14)__classcall__()
# -> instance = typecall(cls, *args, **options)
#   /home/philipblaine/.sage/temp/DESKTOP-27I4PM7/489/parametric.sageld7ifo68.py(1762)__init__()
# -> h = family(**test_point)
#   /mnt/c/users/phili/SAGEMATH/cutgeneratingfunctionology/cutgeneratingfunctionology/igp/parametric_family.py(134)__call__()
# -> return self._element_constructor_(**kwds)
#   /mnt/c/users/phili/SAGEMATH/cutgeneratingfunctionology/cutgeneratingfunctionology/igp/parametric_family.py(164)_element_constructor_()
# -> element = self._construct_function(**values)
#   <string>(38)setup_portfolio_lp()
#   /mnt/c/users/phili/SAGEMATH/sage-9.3.beta7/local/lib/python3.8/site-packages/sage/categories/sets_cat.py(993)_element_constructor_from_element_class()
# -> return self.element_class(self, *args, **keywords)
# > /mnt/c/users/phili/SAGEMATH/cutgeneratingfunctionology/cutgeneratingfunctionology/spam/parametric_real_field_element.py(61)__init__()
# -> RR(value)
#   /mnt/c/users/phili/SAGEMATH/cutgeneratingfunctionology/cutgeneratingfunctionology/spam/parametric_real_field_element.py(153)_richcmp_()
# -> left.parent().assume_comparison(right, operator.lt, left)
#   /home/philipblaine/.sage/temp/DESKTOP-27I4PM7/489/parametric.sageld7ifo68.py(964)assume_comparison()
# -> self.record_factor(new_fac, op)
#   /home/philipblaine/.sage/temp/DESKTOP-27I4PM7/489/parametric.sageld7ifo68.py(1109)record_factor()->None
# -> pdb.set_trace()
# (Pdb) down
# > /mnt/c/users/phili/SAGEMATH/cutgeneratingfunctionology/cutgeneratingfunctionology/spam/parametric_real_field_element.py(153)_richcmp_()
# -> left.parent().assume_comparison(right, operator.lt, left)
# (Pdb) down
# > /home/philipblaine/.sage/temp/DESKTOP-27I4PM7/489/parametric.sageld7ifo68.py(964)assume_comparison()
# -> self.record_factor(new_fac, op)
# (Pdb) down
# > /home/philipblaine/.sage/temp/DESKTOP-27I4PM7/489/parametric.sageld7ifo68.py(1109)record_factor()->None
# -> pdb.set_trace()
# (Pdb) down
# *** Newest frame
# (Pdb) up
# > /home/philipblaine/.sage/temp/DESKTOP-27I4PM7/489/parametric.sageld7ifo68.py(964)assume_comparison()
# -> self.record_factor(new_fac, op)
# (Pdb) up
# > /mnt/c/users/phili/SAGEMATH/cutgeneratingfunctionology/cutgeneratingfunctionology/spam/parametric_real_field_element.py(153)_richcmp_()
# -> left.parent().assume_comparison(right, operator.lt, left)
# (Pdb) up
# > /mnt/c/users/phili/SAGEMATH/cutgeneratingfunctionology/cutgeneratingfunctionology/spam/parametric_real_field_element.py(61)__init__()
# -> RR(value)
# (Pdb) up
# > /mnt/c/users/phili/SAGEMATH/sage-9.3.beta7/local/lib/python3.8/site-packages/sage/categories/sets_cat.py(993)_element_constructor_from_element_class()
# -> return self.element_class(self, *args, **keywords)
# (Pdb) up
# > <string>(38)setup_portfolio_lp()
# (Pdb) list
# [EOF]
# (Pdb) up
# > /mnt/c/users/phili/SAGEMATH/cutgeneratingfunctionology/cutgeneratingfunctionology/igp/parametric_family.py(164)_element_constructor_()
# -> element = self._construct_function(**values)
# (Pdb) down
# > <string>(38)setup_portfolio_lp()
# (Pdb) down
# > /mnt/c/users/phili/SAGEMATH/sage-9.3.beta7/local/lib/python3.8/site-packages/sage/categories/sets_cat.py(993)_element_constructor_from_element_class()
# -> return self.element_class(self, *args, **keywords)
# (Pdb) down
# > /mnt/c/users/phili/SAGEMATH/cutgeneratingfunctionology/cutgeneratingfunctionology/spam/parametric_real_field_element.py(61)__init__()
# -> RR(value)
# (Pdb) list
#  56  	            ## Test coercing the value to RR, so that we do not try to build a ParametricRealFieldElement
#  57  	            ## from something like a tuple or vector or list or variable of a polynomial ring
#  58  	            ## or something else that does not make any sense.
#  59  	            from sage.interfaces.mathematica import MathematicaElement
#  60  	            if not isinstance(value, MathematicaElement):
#  61  ->	                RR(value)
#  62  	            self._val = value
#  63  	        if symbolic is None:
#  64  	            self._sym = value # changed to not coerce into SR. -mkoeppe
#  65  	        else:
#  66  	            self._sym = symbolic
# (Pdb) p value
# INFO: 2021-03-25 17:11:32,927 New constraint: mu - 8000/41 < 0
# INFO: 2021-03-25 17:11:32,951 New constraint: mu - 6000/59 < 0
# INFO: 2021-03-25 17:11:32,972 New constraint: mu - 12000/179 < 0
# (6047/6000*mu)~ - (41/8000*mu)~*x_0 + (59/6000*mu)~*x_1 + (179/12000*mu)~*x_2 + (107/24000*mu)~*x_3 + (29/8000*mu)~*x_4 + (19/8000*mu)~*x_5 + (17/24000*mu)~*x_6 + (1/125*mu)~*x_7 - 1/24*x_8 - 1/24*x_9 - 1/24*x_10 - 1/24*x_11 - 1/24*x_12 - 1/24*x_13 - 1/24*x_14 - 1/24*x_15 - 1/24*x_16 - 1/24*x_17 - 1/24*x_18 - 1/24*x_19 - 1/24*x_20 - 1/24*x_21 - 1/24*x_22 - 1/24*x_23 - 1/24*x_24 - 1/24*x_25 - 1/24*x_26 - 1/24*x_27 - 1/24*x_28 - 1/24*x_29 - 1/24*x_30 - 1/24*x_31
# (Pdb) up
# > /mnt/c/users/phili/SAGEMATH/sage-9.3.beta7/local/lib/python3.8/site-packages/sage/categories/sets_cat.py(993)_element_constructor_from_element_class()
# -> return self.element_class(self, *args, **keywords)
# (Pdb) up
# > <string>(38)setup_portfolio_lp()
# (Pdb) up
# > /mnt/c/users/phili/SAGEMATH/cutgeneratingfunctionology/cutgeneratingfunctionology/igp/parametric_family.py(164)_element_constructor_()
# -> element = self._construct_function(**values)
# (Pdb) list
# 159  	                if self in args[0]._parametric_families:
# 160  	                    return args[0]
# 161  	            except AttributeError:
# 162  	                pass
# 163  	        values = self._args_with_defaults(*args, **options)
# 164  ->	        element = self._construct_function(**values)
# 165  	        try:
# 166  	            if not hasattr(element, "_parametric_families"):
# 167  	                element._parametric_families = dict()
# 168  	            element._parametric_families[self] = values
# 169  	        except AttributeError:
# (Pdb) up
# > /mnt/c/users/phili/SAGEMATH/cutgeneratingfunctionology/cutgeneratingfunctionology/igp/parametric_family.py(134)__call__()
# -> return self._element_constructor_(**kwds)
# (Pdb) exit
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-de435918363f> in <module>
#       3 bddbsa.add_linear_constraint((-Integer(1),), Integer(0), operator.lt)
#       4 complex = SemialgebraicComplex(setup_portfolio_lp, ['mu'], find_region_type=solve_for_optimal_portfolio, bddbsa=bddbsa, hist_data=portfolio2_data)
# ----> 5 complex.bfs_completion(var_value=[Integer(10)])
#
# /mnt/c/users/phili/SAGEMATH/cutgeneratingfunctionology/cutgeneratingfunctionology/igp/__init__.py in bfs_completion(self, var_value, flip_ineq_step, check_completion, wall_crossing_method, goto_lower_dim, max_failings)
#    2404                 var_value = list(var_value)
#    2405                 if not self.is_point_covered(var_value):
# -> 2406                     self.add_new_component(var_value, bddbsa=bddbsa, polynomial_map=polynomial_map, pos_poly=no_crossing, flip_ineq_step=flip_ineq_step, wall_crossing_method=wall_crossing_method, goto_lower_dim=goto_lower_dim, num_eq=num_eq)
#    2407             max_num_eq = max(self.points_to_test.keys())
#    2408             num_eq += _sage_const_1
#
# /mnt/c/users/phili/SAGEMATH/cutgeneratingfunctionology/cutgeneratingfunctionology/igp/__init__.py in add_new_component(self, var_value, bddbsa, polynomial_map, pos_poly, flip_ineq_step, wall_crossing_method, goto_lower_dim, num_eq)
#    2158             if not num_eq in self.tested_points:
#    2159                 self.tested_points[num_eq] = set([])
# -> 2160         new_component = self._cell_class(self.family, var_value,
#    2161                                          find_region_type=self.find_region_type, bddbsa=bddbsa, polynomial_map=polynomial_map)
#    2162
#
# /mnt/c/users/phili/SAGEMATH/sage-9.3.beta7/local/lib/python3.8/site-packages/sage/misc/classcall_metaclass.pyx in sage.misc.classcall_metaclass.ClasscallMetaclass.__call__ (build/cythonized/sage/misc/classcall_metaclass.c:1761)()
#     320         """
#     321         if cls.classcall is not None:
# --> 322             return cls.classcall(cls, *args, **kwds)
#     323         else:
#     324             # Fast version of type.__call__(cls, *args, **kwds)
#
# /mnt/c/users/phili/SAGEMATH/cutgeneratingfunctionology/cutgeneratingfunctionology/igp/__init__.py in __classcall__(cls, family, var_value, find_region_type, bddbsa, polynomial_map)
#    1671             family = ParametricFamily(family)
#    1672         var_value = tuple(var_value)
# -> 1673         return super(ProofCell, cls).__classcall__(cls, family, var_value, find_region_type, bddbsa, polynomial_map)
#    1674
#    1675     @staticmethod
#
# /mnt/c/users/phili/SAGEMATH/cutgeneratingfunctionology/cutgeneratingfunctionology/igp/class_call.py in __classcall__(cls, *args, **options)
#      12     @staticmethod
#      13     def __classcall__(cls, *args, **options):
# ---> 14         instance = typecall(cls, *args, **options)
#      15         assert isinstance( instance, cls )
#      16         instance._init_args = (cls, args, options)
#
# /mnt/c/users/phili/SAGEMATH/sage-9.3.beta7/local/lib/python3.8/site-packages/sage/misc/classcall_metaclass.pyx in sage.misc.classcall_metaclass.typecall (build/cythonized/sage/misc/classcall_metaclass.c:2223)()
#     484             TypeError: Argument 'cls' has incorrect type (expected type, got classobj)
#     485     """
# --> 486     return (<PyTypeObject*>type).tp_call(cls, args, kwds)
#     487
#     488 # Class for timing::
#
# /mnt/c/users/phili/SAGEMATH/cutgeneratingfunctionology/cutgeneratingfunctionology/igp/__init__.py in __init__(self, family, var_value, find_region_type, bddbsa, polynomial_map)
#    1760         K, pt, test_point = self._construct_field_and_test_point(family, var_value, polynomial_map)
#    1761         try:
# -> 1762             h = family(**test_point)
#    1763         except Exception:
#    1764             # Function is non-constructible at this random point.
#
# <string> in solve_for_optimal_portfolio(K, lp)
#
# AttributeError: 'NoneType' object has no attribute 'solve'

# %%
complex.is_point_covered([1])
