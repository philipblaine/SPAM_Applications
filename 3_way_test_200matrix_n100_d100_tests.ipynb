# %%
# input matrix A should be the same as program-reconstructed matrix LP_A
# here, since A has at least one "0" entry, LP.constraints() does not display this
# and so LP_A does not record the "0" entry, resulting in LP_A being non-square
import sys
import cProfile

sys.path.append("/mnt/c/users/phili/SAGEMATH/SPAM_Applications")
load_attach_path("/mnt/c/users/phili/SAGEMATH/SPAM_Applications")
load("startup.sage")

from sage.numerical.interactive_simplex_method import *
from sage.numerical.backends.generic_backend import get_solver

matrix_dim = 200
nbound = 100
dbound = 100

A = random_matrix(QQ,matrix_dim,matrix_dim,num_bound=nbound,den_bound=dbound)
Y = random_matrix(QQ,matrix_dim,1,num_bound=nbound,den_bound=dbound)
c = random_matrix(QQ,matrix_dim,1,num_bound=nbound,den_bound=dbound)

for i in range(len(vector(c))):
    if c[i] <= 0:
        c[i] = 1/100
        
for i in range(len(vector(Y))):
    if Y[i] <= 0:
        Y[i] = 1/100
        
c = vector(c)
Y = vector(Y)

# %%
LP = MixedIntegerLinearProgram(maximization=True,solver="GLPK")
x = LP.new_variable(nonnegative=True)
LP.add_constraint(A*x <= Y)
LP.set_objective(c)

# %%
cProfile.run("intsol = exact_optsol_intLP(LP)")
# Out:
#          768469 function calls (768278 primitive calls) in 96.609 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        21    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1017(_handle_fromlist)
#     40230    0.022    0.000    0.030    0.000 <frozen importlib._bootstrap>:389(parent)
#         1    0.018    0.018   96.609   96.609 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <string>:1(__new__)
#         1    0.000    0.000    0.000    0.000 <string>:33(<listcomp>)
#         1    8.771    8.771   96.591   96.591 <string>:5(exact_optsol_intLP)
#         3    0.000    0.000    0.000    0.000 additive_magmas.py:207(__init_extra__)
#         1    0.000    0.000    0.000    0.000 bimodules.py:124(left_base_ring)
#         1    0.000    0.000    0.000    0.000 bimodules.py:136(right_base_ring)
#         1    0.000    0.000    0.000    0.000 bimodules.py:162(super_categories)
# ...

# %%
cProfile.run("polysol = exact_optsol_poly(LP)")
# Out:
#          2324500 function calls (2324485 primitive calls) in 26.010 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1017(_handle_fromlist)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:103(release)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:143(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:147(__enter__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:151(__exit__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:157(_get_module_lock)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:176(cb)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:211(_call_with_frames_removed)
# ...

# %%
cProfile.run("solsol = exact_optsol_solveright(LP)")
# Out:
#          2181471 function calls (2179236 primitive calls) in 220.803 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1017(_handle_fromlist)
#     41318    0.016    0.000    0.022    0.000 <frozen importlib._bootstrap>:389(parent)
#         1    0.006    0.006  220.803  220.803 <string>:1(<module>)
#         2    0.000    0.000    0.000    0.000 <string>:1(__new__)
#         1    1.241    1.241  220.797  220.797 <string>:2(exact_optsol_solveright)
#         1    0.000    0.000    0.000    0.000 __init__.py:20(isfunction)
#         2    0.000    0.000    0.000    0.000 abstract_method.py:203(__get__)
#      2511    0.005    0.000    0.005    0.000 additive_magmas.py:207(__init_extra__)
#         2    0.000    0.000    0.000    0.000 bimodules.py:124(left_base_ring)
# ...

# %%
matrix200_n100_d100_A = os.path.join(SAGE_TMP,"A_200_n100_d100.sobj")

# %%
save(A,matrix200_n100_d100_A)

# %%
load(matrix200_n100_d100_A)
# Out:
# 200 x 200 dense matrix over Rational Field (use the '.str()' method to see the entries)

# %%
matrix200_n100_d100_Y = os.path.join(SAGE_TMP,"Y_200_n100_d100.sobj")

# %%
save(Y,matrix200_n100_d100_Y)

# %%
load(matrix200_n100_d100_Y)
# Out:
# (93/46, 1, 1/100, 1/100, 1/100, 1/100, 1/100, 1/100, 17/30, 1/100, 1/100, 1/100, 71/32, 47/20, 67/82, 29/72, 1/100, 1/100, 29/43, 1/100, 1/100, 5/7, 1/100, 1/100, 1/100, 1/100, 1/100, 11/42, 1/100, 83/63, 1/100, 21/4, 1/100, 1/100, 29/15, 1/100, 10/3, 1/100, 1/100, 92/99, 1/100, 1/100, 95/11, 49/93, 1/100, 14/9, 91/45, 1/100, 1/100, 1/100, 1/100, 32/35, 1/100, 1/100, 8/29, 44/49, 1/100, 16/57, 59/5, 1/100, 6/29, 1/100, 1/100, 1/100, 1/100, 1/100, 1/100, 25/2, 1/100, 13/24, 2/5, 1/100, 18/67, 1/100, 23/35, 1/100, 1/100, 49/80, 33/2, 1/100, 1/100, 1/100, 1/100, 39/29, 27/28, 1/100, 1/100, 1/100, 3/79, 14/3, 1/100, 23/30, 21/20, 28/3, 1/100, 1/100, 1/100, 1/100, 4/23, 1/100, 1/100, 1/100, 1/100, 1/100, 88/27, 16/23, 1/100, 55/53, 3/4, 51/44, 1/100, 17/23, 40/81, 1/100, 26/23, 79/80, 1/100, 79/100, 1/100, 8/69, 73/15, 21/2, 92/21, 5/7, 7/9, 27/85, 32/17, 41/56, 1/100, 7/80, 1/100, 86/7, 44/97, 1/100, 1/100, 1/100, 1/100, 1/100, 97/90, 1/100, 1/100, 22/7, 1/100, 79/93, 1/100, 1/100, 1/100
# ...
